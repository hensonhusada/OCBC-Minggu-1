# %%
import requests, json

# %%
headers =  {
    'accept': 'application/json', 
    'X-Api-Token': 'dev'
}
fetch_content = requests.get('http://localhost:8080/psychologytoday/get_articles_urls?page_number=1', headers=headers)

# %%
print(fetch_content.status_code)
if fetch_content.status_code == 200:    
    urls_content = json.loads(fetch_content.content.decode())
    print(urls_content["message"])
    urls = urls_content["data"]["url_list"]
    for i in urls:
        print(i)
    print(len(urls))    
else:
    urls = None
# Out:
# 200
# Success
# https://www.psychologytoday.com/intl/blog/cultural-animal/202201/why-does-getting-rejected-strangers-matter
# https://www.psychologytoday.com/intl/blog/the-pathways-experience/202201/personality-props-material-objects-and-the-self
# https://www.psychologytoday.com/intl/blog/love-digitally/202201/does-social-media-influence-the-motivation-exercise
# https://www.psychologytoday.com/intl/blog/in-the-name-love/202201/4-characteristics-good-romantic-compromises
# https://www.psychologytoday.com/intl/blog/dating-and-mating/202201/can-new-condom-improve-sexual-pleasure-men-and-women
# https://www.psychologytoday.com/intl/blog/deviced/202201/feeling-stagnant-during-covid
# https://www.psychologytoday.com/intl/blog/finding-new-home/202201/new-research-life-satisfaction-among-single-people
# https://www.psychologytoday.com/intl/blog/imperfect-spirituality/202201/strategy-can-help-you-make-healthier-food-choices
# https://www.psychologytoday.com/intl/blog/changing-minds/202201/3-ways-be-better-listener-your-kids
# https://www.psychologytoday.com/intl/blog/how-do-life/202201/pursue-excellence-its-own-sake
# https://www.psychologytoday.com/intl/blog/intersubjective/202201/examining-jane-austens-persuasion-and-the-concept-core-affect
# https://www.psychologytoday.com/intl/blog/singletons/202201/rethinking-football-beautiful-life-until-it-wasnt
# https://www.psychologytoday.com/intl/blog/communications-matter/202201/what-happens-when-you-see-red
# https://www.psychologytoday.com/intl/blog/lets-face-it/202201/why-we-use-language-disgust-describe-political-foes
# https://www.psychologytoday.com/intl/blog/intimacy-path-toward-spirituality/202201/4-tips-becoming-more-generous-listener
# https://www.psychologytoday.com/intl/blog/rethink-your-way-the-good-life/202201/8-slightly-quirky-ways-reclaim-your-mental-health
# https://www.psychologytoday.com/intl/blog/compassionate-warriors/202201/beating-the-bad-habit-blaming-others
# https://www.psychologytoday.com/intl/blog/drawing-the-curtains-back/202201/get-know-your-dark-side-through-stories
# https://www.psychologytoday.com/intl/blog/fulfillment-any-age/202201/5-signs-someone-is-trying-fake-you-out
# https://www.psychologytoday.com/intl/blog/brainspotting/202201/hypergraphia-neglected-sign-in-neurology
# https://www.psychologytoday.com/intl/blog/between-the-generations/202201/33-stories-people-tell-about-their-feelings
# https://www.psychologytoday.com/intl/blog/social-instincts/202201/when-do-attractive-alternatives-threaten-your-relationship
# https://www.psychologytoday.com/intl/blog/be-in-the-know/202201/how-get-hooked-making-effort
# https://www.psychologytoday.com/intl/blog/finding-love-the-scientific-take/202201/defining-internet-infidelity
# https://www.psychologytoday.com/intl/blog/tech-happy-life/202201/the-purpose-and-problem-suffering
# https://www.psychologytoday.com/intl/blog/psychology-tomorrow/202201/why-is-wordle-so-popular
# https://www.psychologytoday.com/intl/blog/finding-purpose/202201/the-brain-prediction-machine-the-key-the-self
# https://www.psychologytoday.com/intl/blog/nurturing-resilience/202201/if-your-energy-is-low-where-do-you-find-more
# https://www.psychologytoday.com/intl/blog/being-your-best-self/202201/working-through-tradeoffs-is-key-your-personal-growth-and-success
# https://www.psychologytoday.com/intl/blog/immigrant-stories/202201/mindfulness-is-key-happiness-in-modern-mental-health
# https://www.psychologytoday.com/intl/blog/science-choice/202201/3-keys-better-decisions
# https://www.psychologytoday.com/intl/blog/making-the-whole-beautiful/202201/dismissing-and-diminishing-your-past-keeps-you-healing
# 1

# %%
if fetch_content.status_code == 200:
    complete_data = []
    base_url = "http://localhost:8080/psychologytoday/get_article_detail?url="
    for i in urls:
        url = base_url + i
        # print("="*98)
        print("Fetching", url)
        try:
            detail_content = requests.get(url, headers=headers)
            response = json.loads(detail_content.content.decode())
            print(response['status'])
            complete_data.append(response['data'])
            print(response['data']['title'])
            # print(response['data']['author'])
            # print(response['data']['magazine'])
            print("="*98)
        except Exception as e:
            print("Error:", str(e))
        break
    print("All Done")

# %%
headers = {
            "User-Agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Mobile Safari/537.36",
            "Accept-Language": "en-US,en;q=0.9,id;q=0.8,ms;q=0.7,ja;q=0.6,ko;q=0.5"
        }
just_test = requests.get("https://www.psychologytoday.com/intl/blog/invisible-bruises/202201/are-trauma-survivors-able-have-healthy-relationships", headers=headers)

# %%
print(just_test.status_code)
print(just_test.content)
# Out:
# 200
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">\n  <head>\n    <title>Are Trauma Survivors Able to Have Healthy Relationships? | Psychology Today</title>\n    <meta charset="utf-8" http-equiv="Content-Type" content="text/html" />\n<script>window.dataLayer = window.dataLayer || []; window.dataLayer.push({"":"Psychology Today","entityLangcode":"en","page_type":"node","drupal_node_type":"blog_entry","drupal_node_nid":"1171525","drupal_node_title":"Are Trauma Survivors Able to Have Healthy Relationships?","userUid":0,"event":"drupal_node_view","ContentWeb":"Blogs"});</script>\n<link rel="canonical" href="https://www.psychologytoday.com/intl/blog/invisible-bruises/202201/are-trauma-survivors-able-have-healthy-relationships" />\n<meta name="description" content="Identifying unhealthy or even dangerous patterns empowers us to grow." />\n<meta property="fb:app_id" content="220580041311284" />\n<meta property="og:site_name" content="Psychology Today" />\n<meta property="og:type" content="article" />\n<meta property="og:url" content="https://www.psychologytoday.com/intl/blog/invisible-bruises/202201/are-trauma-survivors-able-have-healthy-relationships" />\n<meta property="og:title" content="Are Trauma Survivors Able to Have Healthy Relationships?" />\n<meta property="og:description" content="Identifying unhealthy or even dangerous patterns empowers us to grow." />\n<meta property="og:image" content="https://cdn2.psychologytoday.com/assets/styles/manual_crop_1_91_1_1528x800/public/field_blog_entry_teaser_image/2022-01/couple-relationship-g5a35baa48_1920.jpg?itok=MGT0FrJv" />\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:description" content="Identifying unhealthy or even dangerous patterns empowers us to grow." />\n<meta name="twitter:site" content="@PsychToday" />\n<meta name="twitter:title" content="Are Trauma Survivors Able to Have Healthy Relationships?" />\n<meta name="twitter:creator" content="@psychtoday" />\n<meta name="twitter:creator:id" content="27726303" />\n<meta name="twitter:url" content="https://www.psychologytoday.com/intl/blog/invisible-bruises/202201/are-trauma-survivors-able-have-healthy-relationships" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<meta http-equiv="x-dns-prefetch-control" content="on" />\n<meta name="theme-color" content="#191C1F" media="(prefers-color-scheme: dark)" />\n<meta name="theme-color" content="#F2F2F2" media="(prefers-color-scheme: light)" />\n<meta name="alexaVerifyID" content="ruuD3Gzrr-EaY185APFbxF69Va4" />\n<meta name="google-site-verification" content="G-wasBQCXXJoehIaVW5BsO9VYKt4oqmWGo155wSSakQ" />\n<meta name="y_key" content="0f29d521db0a2863" />\n<meta name="msvalidate.01" content="9AD6650A37790044983CFB6B27D77607" />\n<meta name="apple-mobile-web-app-capable" content="yes" />\n<meta name="apple-mobile-web-app-title" content="Psych Today" />\n<script type="application/ld+json">{\n    "@context": "https://schema.org",\n    "@graph": [\n        {\n            "@type": "NewsArticle",\n            "headline": "Are Trauma Survivors Able to Have Healthy Relationships?",\n            "description": "The way we experience our first caregiver relationships is usually how we end up managing our romantic relationships unless we do the work to change.",\n            "image": {\n                "@type": "ImageObject",\n                "url": "https://cdn2.psychologytoday.com/assets/styles/manual_crop_1_91_1_1528x800/public/field_blog_entry_teaser_image/2022-01/couple-relationship-g5a35baa48_1920.jpg?itok=MGT0FrJv",\n                "width": "1528",\n                "height": "800"\n            },\n            "datePublished": "2022-01-24T19:52:52-0500",\n            "dateModified": "2022-01-25T07:40:10-0500",\n            "isAccessibleForFree": "True",\n            "author": {\n                "@type": "Person", ...
